# %% [markdown]
# # Assignment 10: Document Classification

# %% [markdown]
# Spooky Authors: Use the dataset of sentences from poems written by Edgar Allen Poe, Mary Shelley, and HP Lovecraft and train models to predict who wrote the sentence, based only on the words in the sentence. Choose either a logistic regression or a classification tree, and use that model for both of the following feature transformations.
# 1. Train a model using word counts (count vectorizer) (25 pts)
# 2. Train a model using TF-IDF (tf-idf vectorizer) (25 pts)
#
# Compare which model performs better using appropriate metrics (25 pts). Make sure to use standard modeling practices such as training and testing data.
#
# What are some words that are used uniquely by each author? (25 pts)
