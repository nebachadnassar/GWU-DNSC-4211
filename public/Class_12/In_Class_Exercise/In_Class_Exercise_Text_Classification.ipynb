# %% [markdown]
# # BBC Machine Learning for Topic Classification

# %% [markdown]
# Use the BBC news data to create Multiclass machine learning model

# %% [markdown]
# Note that we have only looked at `Binary Classification ` models to date. For problems with multiple classes, you can approach multiple ways including `multiple binary classification models` or a `multi class model`.
#
# For this problem just use a multi class model, the y variable for this can be string values.... e.g. just keep the labels column as is!
