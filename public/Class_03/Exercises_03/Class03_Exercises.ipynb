# %% [markdown]
# # Class 04 Exercises

# %% [markdown]
# ## 0. Load in Pandas, Tidyverse

# %% [markdown]
# Python

# %%
import pandas as pd
df = pd.read_csv("day.csv")

# %% [markdown]
# R

# %% [markdown]
# ## 1. Read in the Washington DC Bikeshare dataset (day.csv)

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# ## 2. How many records & columns are there?

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# ## 3. What columns are of interest? What datatypes exist in the data

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# ## 4. What makes a record in the dataset? It may help to print the first couple rows

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# ## 5. What month has the most bikers, on average?

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# ## 6. Create a new column, that gives the months the name, instead of number (e.g. Jan, Feb, Mar instead of 0, 1, 2

# %% [markdown]
# Python

# %%
month_map = {
    1:"Jan",
    2:"Feb",
    3:"Mar",
    4:"Apr",
    5:"May",
    6:"Jun",
    7:"Jul",
    8:"Aug",
    9:"Sep",
    10:"Oct",
    11:"Nov",
    12:"Dec",
}
df["mnth_name"] = df["mnth"].replace(month_map)
df.sample(10)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 117      118  2011-04-28       2   0     4        0        4           1
# 141      142  2011-05-22       2   0     5        0        0           0
# 518      519  2012-06-02       2   1     6        0        6           0
# 25        26  2011-01-26       1   0     1        0        3           1
# 671      672  2012-11-02       4   1    11        0        5           1
# 228      229  2011-08-17       3   0     8        0        3           1
# 238      239  2011-08-27       3   0     8        0        6           0
# 487      488  2012-05-02       2   1     5        0        3           1
# 445      446  2012-03-21       2   1     3        0        3           1
# 667      668  2012-10-29       4   1    10        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 117           2  0.617500  0.578929  0.700833   0.320908     569        3489
# ...

# %%
df["dteday_fmt"] = pd.to_datetime(df["dteday"])

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt mnth_name dteday_fmt
# 0   985       Jan 2011-01-01
# ...

# %% [markdown]
# R

# %% [markdown]
# ## 7. Filter the dataset to only have days in July, name it december_df

# %% [markdown]
# Python

# %%
df["mnth"].value_counts()
# Out:
# mnth
# 1     62
# 3     62
# 5     62
# 7     62
# 8     62
# 10    62
# 12    62
# 4     60
# 6     60
# 9     60
# 11    60
# 2     57
# Name: count, dtype: int64

# %%
december_df = df.loc[df["mnth"] == 7]
december_df.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 181      182  2011-07-01       3   0     7        0        5           1
# 182      183  2011-07-02       3   0     7        0        6           0
# 183      184  2011-07-03       3   0     7        0        0           0
# 184      185  2011-07-04       3   0     7        1        1           0
# 185      186  2011-07-05       3   0     7        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 181           1  0.722500  0.652162  0.396250   0.102608    1246        4116
# 182           1  0.738333  0.667308  0.444583   0.115062    2204        2915
# 183           2  0.716667  0.668575  0.682500   0.228858    2282        2367
# 184           2  0.726667  0.665417  0.637917   0.081479    3065        2978
# 185           1  0.746667  0.696338  0.590417   0.126258    1031        3634
#
#       cnt
# 181  5362
# 182  5119
# 183  4649
# 184  6043
# ...

# %% [markdown]
# R

# %% [markdown]
# ## 8. On average, do holidays have more or fewer riders than non holidays

# %% [markdown]
# Python

# %% [markdown]
# R
