# %% [markdown]
# # ASSN_03

# %% [markdown]
# Complete the following questions using the flights dataset. Once complete, upload the ipynb file to Blackboard.

# %% [markdown]
# ## 1. Import the Relevant Data Analysis Packages

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# # 2. Read in the Flights Data, and print out the first 5 rows of the dataset

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# # 3. Write code to find the answers to each question below **seperately**.
#
# - 1a. Had an arrival delay of two or more hours
# - 1b. Flew to Houston (IAH or HOU)
# - 1c. Were operated by United, American, or Delta
# - 1d. Departed in summer (July, August, and September)
# - 1e. Arrived more than two hours late, but didn’t leave late
# - 1f. Made up at least 60 minutes in flight time (hint.. you need to create a new column)
# - 1g. Departed between midnight and 6am (inclusive)

# %% [markdown]
# Python

# %%
#-- a

# %%
#-- b

# %%
#-- c

# %%
#-- d

# %%
#-- e

# %%
#-- f

# %%
#-- g

# %% [markdown]
# R

# %%
#-- a

# %%
#-- b

# %%
#-- c

# %%
#-- d

# %%
#-- e

# %%
#-- f

# %%
#-- g

# %% [markdown]
# # 4. How many flights have a missing dep_time? What other variables are missing? What might these rows represent?

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# # 5. What is the average departure delay time, for each airline? Who has the lowest? The highest? (hint.. group_by functions should be useful)

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# # 6., 7., & 8. Create new dataframes, where you...
# 1. filter the dataset to just American Airlines, Delta, and United Airlines
# 2. Aggregate the dataset so that only the airline field and year are your only columns, and the count of flights in a given year are the values
# 3. Widen the dataset so that each airline is its own column

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# # 9. Clean up the column names of the original flights dataset, to make it more human readable

# %% [markdown]
# Python

# %% [markdown]
# R

# %% [markdown]
# ## 10. Use the following data and create a new dataset merging both artist datasets and the instruments dataset together (only R)

# %% [markdown]
# On the assignment files you will see csv files named `band_instruments.csv` and `band_members.csv`. Members of the rock bands *The Beatles* and *The Bangles*. Read them into dataframes and then merge them together to produce a new dataframe. You should merge them on 'name' (in band_instruments.csv) and 'artist' (in band_members.csv).
