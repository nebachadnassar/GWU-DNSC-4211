# %%
input_num = -98
tally_of_evenly_div = 0

for i in range(2, input_num):
  if input_num % i == 0:
    tally_of_evenly_div += 1


if tally_of_evenly_div == 0:
  print("Number is prime")
else:
  print("Number is not prime")
# Out:
# Number is prime

# %%
[i for i in range(2, -2)]
# Out:
# []
